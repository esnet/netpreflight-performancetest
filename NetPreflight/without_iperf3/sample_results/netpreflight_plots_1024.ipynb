# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
from pylab import *
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 40})
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
rc('axes', linewidth=3)

# %%
#df = pd.read_csv('5mb.csv')

# %%
#df.head()

# %%
df.plot()

# %%
df.plot("sn", ["Throughput"])

# %%
df1 = pd.read_csv('10mb.csv')

# %%
df1.plot("sn", ["Throughput"])

# %%
#df2 = pd.read_csv('combine_plot_5_10.csv')
df2 = pd.read_csv('combine_plot_buffersize_1024.csv')

# %%
df2.head()
# Out:
#    sn  Throughput_5mb  Throughput_10mb  Throughput_20mb  Throughput_50mb  \
# 0   1        0.682610         1.023872         1.638072         0.819118
# 1   2        0.819118         1.023872         1.170119         1.023872
# 2   3        1.023872         1.170119         2.047488         1.365106
# 3   4        1.365106         1.638072         1.023872         0.819118
# 4   5        1.170119         1.365106         1.638072         1.365106
#
#    Throughput_100mb
# 0          0.910121
# 1          0.910121
# 2          0.910121
# 3          0.630105
# 4          0.819118

# %%
df2.plot("sn", ["Throughput_5mb"],linewidth=3,figsize=(21,13))
plt.xlabel('Time')
plt.ylabel('Throughput (Mbps)')
# Out:
# Text(0, 0.5, 'Throughput (Mbps)')

# %%
df2.plot("sn", ["Throughput_10mb"],linewidth=3,figsize=(21,13))
plt.xlabel('Time')
plt.ylabel('Throughput (Mbps)')
# Out:
# Text(0, 0.5, 'Throughput (Mbps)')

# %%
df2.plot("sn", ["Throughput_20mb"],linewidth=3,figsize=(21,13))
plt.xlabel('Time')
plt.ylabel('Throughput (Mbps)')
# Out:
# Text(0, 0.5, 'Throughput (Mbps)')

# %%
df2.plot("sn", ["Throughput_50mb"],linewidth=3,figsize=(21,13))
plt.xlabel('Time')
plt.ylabel('Throughput (Mbps)')
# Out:
# Text(0, 0.5, 'Throughput (Mbps)')

# %%
df2.plot("sn", ["Throughput_100mb"],linewidth=3,figsize=(21,13))
plt.xlabel('Time')
plt.ylabel('Throughput (Mbps)')
# Out:
# Text(0, 0.5, 'Throughput (Mbps)')

# %%
#df2.plot("sn", ["Throughput_5mb","Throughput_10mb"], figsize=(12,8))
df2.plot("sn", ["Throughput_5mb","Throughput_10mb"],linewidth=3,figsize=(21,13))
plt.xlabel('Time')
plt.ylabel('Throughput (Mbps)')
plt.legend(loc=4, prop={'size': 26})

# %%
# df2.plot("sn", ["Throughput_5mb","Throughput_10mb","Throughput_20mb","Throughput_50mb","Throughput_100mb"], figsize=(21,13))
# plt.xlabel("Time(s)")
# plt.ylabel('Throughput (Mbps)')
# plt.legend(loc=0, prop={'size': 26})
