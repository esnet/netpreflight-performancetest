# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
from pylab import *
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 40})
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
rc('axes', linewidth=4)

# %%
pwd
# Out:
# '/Users/bashirm/Documents/largefiles'

# %%
df = pd.read_csv('box_plot_128.csv')

# %%
df.head()
# Out:
#      Tp_5mb   Tp_10mb   Tp_20mb   Tp_50mb  Tp_100mb
# 0  49.23053  36.70238  29.51000  19.10444  11.15467
# 1  47.85024  41.12433  29.94143  18.05993  10.94016
# 2  43.02503  38.35192  30.75066  17.65514  11.42856
# 3  43.20657  40.79665  30.38567  19.17599  11.46695
# 4  48.30166  38.06677  30.20640  18.96293  10.65556

# %%
fig = plt.gcf()

# Changing Seaborn Plot size
fig.set_size_inches(21, 13)

# Setting the font scale
sns.set(font_scale=4, style="white")
sns.boxplot(data=df)
plt.xlabel('Data Transfer at BufferSize S = 128, TCP = Cubic')
plt.ylabel('Throughput (Mbps)')
plt.title('')
plt.show()
