# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
from pylab import *
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 40})
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
rc('axes', linewidth=20)

# %%
pwd
# Out:
# '/Users/bashirm/Documents/largefiles'

# %%
df = pd.read_csv('box_plot_3072.csv')

# %%
df.head()
# Out:
#        Tp_5mb     Tp_10mb    Tp_20mb    Tp_50mb   Tp_100mb
# 0  1054.75942   963.76093  727.09844  444.41149  259.24023
# 1  1019.74681  1007.20899  740.23873  454.26903  266.84010
# 2  1036.95765   986.98399  775.26569  446.02460  268.88373
# 3  1050.25192  1007.20899  767.99760  449.28620  266.55069
# 4  1159.23981  1019.74681  727.09844  446.83555  269.47339

# %%
fig = plt.gcf()

# Changing Seaborn Plot size
fig.set_size_inches(21, 13)

# Setting the font scale
sns.set(font_scale=4, style="white" )
sns.boxplot(data=df)
plt.xlabel('Data Transfer at BufferSize S = 3072, TCP = Cubic')
plt.ylabel('Throughput (Mbps)')
plt.title('')
# plt.show()
# Out:
# Text(0.5, 1.0, '')
