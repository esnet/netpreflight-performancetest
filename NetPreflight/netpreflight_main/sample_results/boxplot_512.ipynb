# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
from pylab import *
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 40})
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
rc('axes', linewidth=3)

# %%
pwd
# Out:
# '/Users/bashirm/Documents/largefiles'

# %%
df = pd.read_csv('box_plot_512.csv')

# %%
df.head()
# Out:
#       Tp_5mb    Tp_10mb    Tp_20mb   Tp_50mb  Tp_100mb
# 0  189.62875  171.38004  120.82560  75.01818  44.71611
# 1  193.20664  166.50339  127.20457  72.88243  44.52169
# 2  199.80390  166.50339  126.41936  75.57182  44.09037
# 3  176.55096  170.66596  124.87767  71.73367  45.66327
# 4  187.03111  154.56545  120.82560  75.43264  43.62083

# %%
fig = plt.gcf()

# Changing Seaborn Plot size
fig.set_size_inches(21, 13)

# Setting the font scale
sns.set(font_scale=4, style="white" )
sns.boxplot(data=df)
plt.xlabel('Data Transfer at BufferSize S = 512, TCP = Cubic')
plt.ylabel('Throughput (Mbps)')
plt.show()
